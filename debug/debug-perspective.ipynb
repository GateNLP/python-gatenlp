# %% [markdown]
# # Try Perspective Annotator

# %%
import os
import json
from gatenlp import Document, Span
from gatenlp.processing.client.perspective import PerspectiveAnnotator
from gatenlp.lib_spacy import AnnSpacy

# %%
apikey = os.environ["PERSPECTIVE_KEY"]

# %%
texts = [
    """
    This is just some example text. Has a sentence that talks about shit in general. And another
    talking about 💩💩💩💩 in general. Donald Trump is a moron.
    """,
    "What a stupid bitch she is.",
    "What a stupid paki bitch she is."
]
docs = [Document(t) for t in texts]

# %%
anntr = AnnSpacy()
for doc in docs:
    doc = anntr(doc)
# Out:
# /home/johann/software/anaconda/envs/gatenlp-37/lib/python3.7/site-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_core_web_sm' (3.2.0) was trained with spaCy v3.2 and may not be 100% compatible with the current version (3.3.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# annotate documents as a whole
perspective1 = PerspectiveAnnotator(auth_token=apikey, requested_attributes=["TOXICITY"])
for doc in docs:
    doc.features.clear()
    perspective1(doc)
    print(doc.features)
# Out:
# 2022-11-09 21:25:39,049|INFO|googleapiclient.discovery_cache|file_cache is only supported with oauth2client<4.0.0
# Features({'TOXICITY_PROBABILITY': 0.85173553, 'languages': ['en']})
# Features({'TOXICITY_PROBABILITY': 0.96426713, 'languages': ['en']})
# Features({'TOXICITY_PROBABILITY': 0.96426713, 'languages': ['en']})

# %%
# annotate sentences
perspective2 = PerspectiveAnnotator(
    auth_token=apikey, langs=["en"], ann_type="Sentence", requested_attributes=["TOXICITY"])
for doc in docs:
    perspective2(doc)
# Out:
# 2022-11-09 21:25:56,520|INFO|googleapiclient.discovery_cache|file_cache is only supported with oauth2client<4.0.0

# %%
docs[0]
# Out:
# Document(
#     This is just some example text. Has a sentence that talks about shit in general. And another
#     talking about 💩💩💩💩 in general. Donald Trump is a moron.
#     ,features=Features({'TOXICITY_PROBABILITY': 0.85173553, 'languages': ['en'], '__idx_139969000581392': 0}),anns={'': AnnotationSet([Annotation(0,5,SpaceToken,features=Features({'_i': 0, 'is_alpha': False, 'is_bracket': False, 'is_currency': False, 'is_digit': False, 'is_left_punct': False, 'is_lower': False, 'is_oov': True, 'is_punct': False, 'is_quote': False, 'is_right_punct': False, 'is_sent_start': True, 'is_space': True, 'is_stop': False, 'is_title': False, 'is_upper': False, 'lang': 'en', 'lemma': '\n    ', 'like_email': False, 'like_num': False, 'like_url': False, 'orth': 16653187200892370574, 'pos': 'SPACE', 'prefix': '\n', 'prob': -20.0, 'rank': 18446744073709551615, 'sentiment': 0.0, 'tag': '_SP', 'shape': '\n    ', 'suffix': '   ', 'ent_type': '', 'dep': 'dep', 'head': 3, 'left_edge': 0, 'right_edge': 0}),id=0), Annotation(0,36,Sentence,features=Features({'TOXICITY_PROBABILITY': 0.050078966, 'languages': ['en']}),id=65), Annotation(5,9,Token,features=Features({'_i': 1, 'is_alpha': True, 'is_bracket': False, 'is_currency': False, 'is_digit': False, 'is_left_punct': False, 'is_lower': False, 'is_oov': True, 'is_punct': False, 'is_quote': False, 'is_right_punct': False, 'is_sent_start': False, 'is_space': False, 'is_stop': True, 'is_title': True, 'is_upper': False, 'lang': 'en', 'lemma': 'this', 'like_email': False, 'like_num': False, 'like_url': False, 'orth': 12943039165150086467, 'pos': 'PRON', 'prefix': 'T', 'prob': -20.0, 'rank': 18446744073709551615, 'sentiment': 0.0, 'tag': 'DT', 'shape': 'Xxxx', 'suffix': 'his', 'ent_type': '', 'dep': 'nsubj', 'head': 3, 'left_edge': 1, 'right_edge': 1}),id=1), Annotation(5,9,NounChunk,features=Features({}),id=70), Annotation(9,10,SpaceToken,features=Features({'is_space': True}),id=2), Annotation(10,12,Token,features=Features({'_i': 2, 'is_alpha': True, 'is_bracket': False, 'is_currency': False, 'is_digit': False, 'is_left_punct': False, 'is_lower': True, 'is_oov': True, 'is_punct': False, 'is_quote': False, 'is_right_punct': False, 'is_sent_start': False, 'is_space': False, 'is_stop': True, 'is_title': False, 'is_upper': False, 'lang': 'en', 'lemma': 'be', 'like_email': False, 'like_num': False, 'like_url': False, 'orth': 3411606890003347522, 'pos': 'AUX', 'prefix': 'i', 'prob': -20.0, 'rank': 18446744073709551615, 'sentiment': 0.0, 'tag': 'VBZ', 'shape': 'xx', 'suffix': 'is', 'ent_type': '', 'dep': 'ROOT', 'head': 3, 'left_edge': 0, 'right_edge': 12}),id=3), Annotation(12,13,SpaceToken,features=Features({'is_space': True}),id=4), Annotation(13,17,Token,features=Features({'_i': 3, 'is_alpha': True, 'is_bracket': False, 'is_currency': False, 'is_digit': False, 'is_left_punct': False, 'is_lower': True, 'is_oov': True, 'is_punct': False, 'is_quote': False, 'is_right_punct': False, 'is_sent_start': False, 'is_space': False, 'is_stop': True, 'is_title': False, 'is_upper': False, 'lang': 'en', 'lemma': 'just', 'like_email': False, 'like_num': False, 'like_url': False, 'orth': 7148522813498185515, 'pos': 'ADV', 'prefix': 'j', 'prob': -20.0, 'rank': 18446744073709551615, 'sentiment': 0.0, 'tag': 'RB', 'shape': 'xxxx', 'suffix': 'ust', 'ent_type': '', 'dep': 'advmod', 'head': 11, 'left_edge': 5, 'right_edge': 5}),id=5), Annotation(13,35,NounChunk,features=Features({}),id=71), Annotation(17,18,SpaceToken,features=Features({'is_space': True}),id=6), Annotation(18,22,Token,features=Features({'_i': 4, 'is_alpha': True, 'is_bracket': False, 'is_currency': False, 'is_digit': False, 'is_left_punct': False, 'is_lower': True, 'is_oov': True, 'is_punct': False, 'is_quote': False, 'is_right_punct': False, 'is_sent_start': False, 'is_space': False, 'is_stop': True, 'is_title': False, 'is_upper': False, 'lang': 'en', 'lemma': 'some', 'like_email': False, 'like_num': False, 'like_url': False, 'orth': 7000492816108906599, 'pos': 'DET', 'prefix': 's', 'prob': -20.0, 'rank': 18446744073709551615, 'sentiment': 0.0, 'tag': 'DT', 'shape': 'xxxx', 'suffix': 'ome', 'ent_type': '', 'dep': 'det', 'head': 1 ...

# %%
perspective1.client.comments
# Out:
# <bound method Resource._add_nested_resources.<locals>.createResourceMethod.<locals>.methodResource of <googleapiclient.discovery.Resource object at 0x7f4d12580090>>
